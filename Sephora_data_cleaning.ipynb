# %%
import pandas as pd

# %%
df_products = pd.read_csv("Sephora_product_review/product_info.csv")
df_products.head()
# Out:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    Fragrance Discovery Set      6342      19-69         6320
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews            size                      variation_type  \
# 0  3.6364     11.0             NaN                                 NaN
# 1  4.1538     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 2  4.2500     16.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 3  4.4762     21.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 4  3.2308     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
#
#   variation_value  ... online_only out_of_stock  sephora_exclusive  \
# ...

# %%
df_products.columns
# Out:
# Index(['product_id', 'product_name', 'brand_id', 'brand_name', 'loves_count',
#        'rating', 'reviews', 'size', 'variation_type', 'variation_value',
#        'variation_desc', 'ingredients', 'price_usd', 'value_price_usd',
#        'sale_price_usd', 'limited_edition', 'new', 'online_only',
#        'out_of_stock', 'sephora_exclusive', 'highlights', 'primary_category',
#        'secondary_category', 'tertiary_category', 'child_count',
#        'child_max_price', 'child_min_price'],
#       dtype='object')

# %%
columns_to_drop = ['child_count', 'child_max_price', 'child_min_price']
df_products_clean = df_products.drop(columns=columns_to_drop)
df_products_clean.head()
# Out:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    Fragrance Discovery Set      6342      19-69         6320
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews            size                      variation_type  \
# 0  3.6364     11.0             NaN                                 NaN
# 1  4.1538     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 2  4.2500     16.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 3  4.4762     21.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 4  3.2308     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
#
#   variation_value  ... sale_price_usd limited_edition  new  online_only  \
# ...

# %%
df_products_clean.isnull().sum()
# Out:
# product_id               0
# product_name             0
# brand_id                 0
# brand_name               0
# loves_count              0
# rating                 278
# reviews                278
# size                  1631
# variation_type        1444
# variation_value       1598
# variation_desc        7244
# ingredients            945
# price_usd                0
# value_price_usd       8043
# sale_price_usd        8224
# limited_edition          0
# new                      0
# online_only              0
# out_of_stock             0
# sephora_exclusive        0
# highlights            2207
# primary_category         0
# secondary_category       8
# tertiary_category      990
# dtype: int64

# %%
# Fill 'size' and 'ingredients' with 'Unknown'
df_products_clean['size'] = df_products_clean['size'].fillna("Unknown")
df_products_clean['ingredients'] = df_products_clean['ingredients'].fillna("Unknown")

# Drop rows where price_usd is missing
df_products_clean = df_products_clean.dropna(subset=['price_usd'])

# Reset index
df_products_clean = df_products_clean.reset_index(drop=True)

df_products_clean.head()
# Out:
#   product_id               product_name  brand_id brand_name  loves_count  \
# 0    P473671    Fragrance Discovery Set      6342      19-69         6320
# 1    P473668    La Habana Eau de Parfum      6342      19-69         3827
# 2    P473662  Rainbow Bar Eau de Parfum      6342      19-69         3253
# 3    P473660       Kasbah Eau de Parfum      6342      19-69         3018
# 4    P473658  Purple Haze Eau de Parfum      6342      19-69         2691
#
#    rating  reviews            size                      variation_type  \
# 0  3.6364     11.0         Unknown                                 NaN
# 1  4.1538     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 2  4.2500     16.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 3  4.4762     21.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
# 4  3.2308     13.0  3.4 oz/ 100 mL  Size + Concentration + Formulation
#
#   variation_value  ... sale_price_usd limited_edition  new  online_only  \
# ...

# %%
import os
import pandas as pd

# Folder where you stored the review files 
review_folder = "Sephora_product_review/reviews" 

# Get list of all CSV files in that folder
review_files = [f for f in os.listdir(review_folder) if f.endswith(".csv")]

# Load and merge all review CSVs
df_reviews = pd.concat([
    pd.read_csv(os.path.join(review_folder, file), dtype=str) for file in review_files
], ignore_index=True)

df_reviews.head()
# Out:
#   Unnamed: 0    author_id rating is_recommended helpfulness  \
# 0          0   1741593524      5            1.0         1.0
# 1          1  31423088263      1            0.0         NaN
# 2          2   5061282401      5            1.0         NaN
# 3          3   6083038851      5            1.0         NaN
# 4          4  47056667835      5            1.0         NaN
#
#   total_feedback_count total_neg_feedback_count total_pos_feedback_count  \
# 0                    2                        0                        2
# 1                    0                        0                        0
# 2                    0                        0                        0
# 3                    0                        0                        0
# 4                    0                        0                        0
#
#   submission_time                                        review_text  \
# 0      2023-02-01  I use this with the Nudestix “Citrus Clean Bal...
# ...

# %%
df_reviews = df_reviews.drop(columns=["Unnamed: 0"], errors="ignore")

df_reviews.head()
# Out:
#      author_id rating is_recommended helpfulness total_feedback_count  \
# 0   1741593524      5            1.0         1.0                    2
# 1  31423088263      1            0.0         NaN                    0
# 2   5061282401      5            1.0         NaN                    0
# 3   6083038851      5            1.0         NaN                    0
# 4  47056667835      5            1.0         NaN                    0
#
#   total_neg_feedback_count total_pos_feedback_count submission_time  \
# 0                        0                        2      2023-02-01
# 1                        0                        0      2023-03-21
# 2                        0                        0      2023-03-21
# 3                        0                        0      2023-03-20
# 4                        0                        0      2023-03-20
#
#                                          review_text  \
# 0  I use this with the Nudestix “Citrus Clean Bal...
# ...

# %%
df_reviews.isnull().sum()
# Out:
# author_id                        0
# rating                           0
# is_recommended              167988
# helpfulness                 561592
# total_feedback_count             0
# total_neg_feedback_count         0
# total_pos_feedback_count         0
# submission_time                  0
# review_text                   1444
# review_title                310654
# skin_tone                   170539
# eye_color                   209628
# skin_type                   111557
# hair_color                  226768
# product_id                       0
# product_name                     0
# brand_name                       0
# price_usd                        0
# dtype: int64

# %%
df_merged = df_reviews.merge(df_products_clean, on='product_id', how='inner')
df_merged.head()
# Out:
#      author_id rating_x is_recommended helpfulness total_feedback_count  \
# 0   1741593524        5            1.0         1.0                    2
# 1  31423088263        1            0.0         NaN                    0
# 2   5061282401        5            1.0         NaN                    0
# 3   6083038851        5            1.0         NaN                    0
# 4  47056667835        5            1.0         NaN                    0
#
#   total_neg_feedback_count total_pos_feedback_count submission_time  \
# 0                        0                        2      2023-02-01
# 1                        0                        0      2023-03-21
# 2                        0                        0      2023-03-21
# 3                        0                        0      2023-03-20
# 4                        0                        0      2023-03-20
#
#                                          review_text  \
# 0  I use this with the Nudestix “Citrus Clean Bal...
# ...

# %%
df_merged.shape
# Out:
# (1094411, 41)

# %%
df_products_clean.shape
# Out:
# (8494, 24)

# %%
df_merged.columns.tolist()
# Out:
# ['author_id',
#  'rating_x',
#  'is_recommended',
#  'helpfulness',
#  'total_feedback_count',
#  'total_neg_feedback_count',
#  'total_pos_feedback_count',
#  'submission_time',
#  'review_text',
#  'review_title',
#  'skin_tone',
#  'eye_color',
#  'skin_type',
#  'hair_color',
#  'product_id',
#  'product_name_x',
#  'brand_name_x',
#  'price_usd_x',
#  'product_name_y',
#  'brand_id',
#  'brand_name_y',
#  'loves_count',
#  'rating_y',
#  'reviews',
#  'size',
#  'variation_type',
#  'variation_value',
#  'variation_desc',
#  'ingredients',
#  'price_usd_y',
#  'value_price_usd',
#  'sale_price_usd',
#  'limited_edition',
#  'new',
#  'online_only',
#  'out_of_stock',
#  'sephora_exclusive',
#  'highlights',
#  'primary_category',
#  'secondary_category',
#  'tertiary_category']

# %%
df_merged = df_merged.rename(columns={
    'rating_x': 'rating',               # user's review rating
    'rating_y': 'avg_rating'            # product's overall average rating
})

# Drop other unnecessary duplicated columns (if you haven’t already)
df_merged = df_merged.drop(columns=[
    'product_name_x', 'brand_name_x', 'price_usd_x'
], errors='ignore')  # errors='ignore' just in case you've already dropped them

df_merged.head()
# Out:
#      author_id rating is_recommended helpfulness total_feedback_count  \
# 0   1741593524      5            1.0         1.0                    2
# 1  31423088263      1            0.0         NaN                    0
# 2   5061282401      5            1.0         NaN                    0
# 3   6083038851      5            1.0         NaN                    0
# 4  47056667835      5            1.0         NaN                    0
#
#   total_neg_feedback_count total_pos_feedback_count submission_time  \
# 0                        0                        2      2023-02-01
# 1                        0                        0      2023-03-21
# 2                        0                        0      2023-03-21
# 3                        0                        0      2023-03-20
# 4                        0                        0      2023-03-20
#
#                                          review_text  \
# 0  I use this with the Nudestix “Citrus Clean Bal...
# ...

# %%
df_merged.to_csv("cleaned_product_reviews.csv")
